# %% [markdown]
# # Google Natural Language API Client
# ## Setup
# [https://cloud.google.com/natural-language/docs/reference/libraries#client-libraries-install-python](https://cloud.google.com/natural-language/docs/reference/libraries#client-libraries-install-python)
#
# Run:
# ```
# export GOOGLE_APPLICATION_CREDENTIALS="[PATH]"
# ```

# %% [markdown]
# ## Sample Code
# Run the below code to make sure you have everything set up. Something should show up similar to:
# ```
# Text: Hello, world!
# Sentiment: 0.300000011921, 0.300000011921
# ```

# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
text = u'Hello, world!'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print('Text: {}'.format(text))
print('Sentiment: {}, {}'.format(sentiment.score, sentiment.magnitude))
# Out:
# Text: Hello, world!
# Sentiment: 0.30000001192092896, 0.30000001192092896

# %%
import gzip

META_CELLPHONE = 'Datasets/meta_Cell_Phones_and_Accessories.json.gz'

def get_documents(file_name):
    g = gzip.open(file_name, 'r')
    results = []
    for line in g:
        document = eval(line)
        results.append(document)
    return results

# %%
all_documents = get_documents(META_CELLPHONE)

# %%
def add_merged_fields(all_documents):
    for document in all_documents:
        description = ''
        title = ''
        if 'description' in document:
            description = document['description']
        if 'title' in document:
            title = document['title']
        document['title_description'] = '{} {}'.format(title, description)

# %%
add_merged_fields(all_documents)

# %%
text = all_documents[0]['title_description']
print(text)
document = types.Document(content=text, type=enums.Document.Type.PLAIN_TEXT)

entities = client.analyze_entities(document=document)
entities
# Out:
# Pink &amp; White 3d Melt Ice-cream Skin Hard Case Cover for Apple Iphone 4 4s Protect Cell Pink & White 3D Melt Ice-Cream Skin Hard Case Cover For Apple iPhone 4 4S Protect Cell
#
# Description:
#
# Compatible with Apple iPhone 4 4G 4S 16/32/64 GB, AT&T;, Verizon, Sprint Protect your phone from scratches, dirt and bumps.
# Precise openings on the protector case to allow access to all controls and features on the phone. 100% Brand New, high quality and
# Easy to Remove and install
# Material: PVC, Hard Plastic
# Color: Pink & White
#
# Package included:
# * 1x Hard Case Cover For iPhone 4 4G 4S
# * 1 Belt Clip
# entities {
#   name: "Pink & White 3D Melt Ice-Cream Skin Hard Case"
#   type: OTHER
#   salience: 0.22059406340122223
#   mentions {
#     text {
#       content: "Cover"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
#   mentions {
#     text {
#       content: "Pink & White 3D Melt Ice-Cream Skin Hard Case"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
#   mentions {
#     text {
#       content: "Cell"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Pink &amp"
#   type: OTHER
#   salience: 0.12564963102340698
#   mentions {
#     text {
#       content: "Pink &amp"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Skin Hard Case Cover"
#   type: WORK_OF_ART
#   salience: 0.12287849187850952
#   mentions {
#     text {
#       content: "Skin Hard Case Cover"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
#   mentions {
#     text {
#       content: "Hard Case Cover"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Apple Iphone 4"
#   type: CONSUMER_GOOD
#   metadata {
#     key: "mid"
#     value: "/g/11b6q3htyx"
#   }
#   salience: 0.10152515769004822
#   mentions {
#     text {
#       content: "Apple Iphone 4"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
#   mentions {
#     text {
#       content: "Apple iPhone 4"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
#   mentions {
#     text {
#       content: "iPhone 4"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
#   mentions {
#     text {
#       content: "iPhone 4"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "White 3d Melt Ice"
#   type: OTHER
#   salience: 0.0862763375043869
#   mentions {
#     text {
#       content: "White 3d Melt Ice"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Cell"
#   type: OTHER
#   salience: 0.03818843886256218
#   mentions {
#     text {
#       content: "Cell"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "protector case"
#   type: OTHER
#   salience: 0.019600583240389824
#   mentions {
#     text {
#       content: "protector case"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Description"
#   type: OTHER
#   salience: 0.01599392481148243
#   mentions {
#     text {
#       content: "Description"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "scratches"
#   type: OTHER
#   salience: 0.01591232605278492
#   mentions {
#     text {
#       content: "scratches"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "bumps"
#   type: OTHER
#   salience: 0.01456710696220398
#   mentions {
#     text {
#       content: "bumps"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "dirt"
#   type: OTHER
#   salience: 0.01456710696220398
#   mentions {
#     text {
#       content: "dirt"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "openings"
#   type: OTHER
#   salience: 0.014514309354126453
#   mentions {
#     text {
#       content: "openings"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "access"
#   type: OTHER
#   salience: 0.014514309354126453
#   mentions {
#     text {
#       content: "access"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "phone"
#   type: OTHER
#   salience: 0.013770007528364658
#   mentions {
#     text {
#       content: "phone"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Apple"
#   type: ORGANIZATION
#   metadata {
#     key: "mid"
#     value: "/m/04st9hr"
#   }
#   salience: 0.011852863244712353
#   mentions {
#     text {
#       content: "Apple"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Material"
#   type: OTHER
#   salience: 0.011825618334114552
#   mentions {
#     text {
#       content: "Material"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Package"
#   type: OTHER
#   salience: 0.011650280095636845
#   mentions {
#     text {
#       content: "Package"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "PVC"
#   type: OTHER
#   salience: 0.01082451082766056
#   mentions {
#     text {
#       content: "PVC"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "4G"
#   type: OTHER
#   metadata {
#     key: "mid"
#     value: "/m/02g9ds"
#   }
#   metadata {
#     key: "wikipedia_url"
#     value: "https://en.wikipedia.org/wiki/4G"
#   }
#   salience: 0.010783874429762363
#   mentions {
#     text {
#       content: "4G"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "4G 4S"
#   type: CONSUMER_GOOD
#   salience: 0.010115574114024639
#   mentions {
#     text {
#       content: "4G 4S"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Sprint"
#   type: ORGANIZATION
#   metadata {
#     key: "mid"
#     value: "/m/077w0b"
#   }
#   metadata {
#     key: "wikipedia_url"
#     value: "https://en.wikipedia.org/wiki/Sprint_Corporation"
#   }
#   salience: 0.009438316337764263
#   mentions {
#     text {
#       content: "Sprint"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "AT&T"
#   type: ORGANIZATION
#   metadata {
#     key: "mid"
#     value: "/m/02d4jl"
#   }
#   metadata {
#     key: "wikipedia_url"
#     value: "https://en.wikipedia.org/wiki/AT%26T_Mobility"
#   }
#   salience: 0.009438316337764263
#   mentions {
#     text {
#       content: "AT&T"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Verizon"
#   type: ORGANIZATION
#   metadata {
#     key: "mid"
#     value: "/m/02d532"
#   }
#   metadata {
#     key: "wikipedia_url"
#     value: "https://en.wikipedia.org/wiki/Verizon_Wireless"
#   }
#   salience: 0.009438316337764263
#   mentions {
#     text {
#       content: "Verizon"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Pink & White"
#   type: ORGANIZATION
#   salience: 0.008059173822402954
#   mentions {
#     text {
#       content: "Pink & White"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "Belt Clip"
#   type: WORK_OF_ART
#   salience: 0.007483834866434336
#   mentions {
#     text {
#       content: "Belt Clip"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "Hard Plastic Color"
#   type: OTHER
#   salience: 0.006415617652237415
#   mentions {
#     text {
#       content: "Hard Plastic\nColor"
#       begin_offset: -1
#     }
#     type: PROPER
#   }
# }
# entities {
#   name: "phone"
#   type: OTHER
#   salience: 0.005449921358376741
#   mentions {
#     text {
#       content: "phone"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "features"
#   type: OTHER
#   salience: 0.004768741317093372
#   mentions {
#     text {
#       content: "features"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "controls"
#   type: OTHER
#   salience: 0.004768741317093372
#   mentions {
#     text {
#       content: "controls"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# entities {
#   name: "quality"
#   type: OTHER
#   salience: 0.004755281377583742
#   mentions {
#     text {
#       content: "quality"
#       begin_offset: -1
#     }
#     type: COMMON
#   }
# }
# language: "en"
